# %% [markdown]
# <a href="https://colab.research.google.com/github/olyadiya/RecSystem_ML/blob/main/ml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ПЛАН
#
# ## Рекомендательная система для соцсети
# - Лента постов, нужно рекомендовать релевантный контент
# - Данные: лайки, репосты, время просмотра, подписки
#
#
#
# ---
#
#
# **Суть работы ленты рекомендаций:**
# 1. Собрать предпочтения пользователя
# 2. Установить, насколько им соответствует каждая единица контента
# 3. Отобрать и показать контент, наиболее подходящий под предпочтения
#
# **Какие данные нужно собирать:**
# 1. Пользователи
# 2. Контент
# 3. User-post interaction
#
#
#
# ---
#
#
#
#
# **1. Архитектура**
# ```
# [вставить Mermaid-код или скриншот] (работаем)
# ```
#
# **2. Структура модулей**
# ```
# project/
# ├── data/
# │   ├── raw/
# │   │   ├── users.csv
# │   │   ├── posts.csv
# │   │   └── interactions.csv
# │   └── processed/
# │
# ├── src/
# │   ├── data/
# │   │   └── load_data.py
# │   ├── features/
# │   │   └── build_features.py
# │   └── models/
# │       └── recommend.py
# │
# ├── notebooks/
# │
# ├── .gitignore
# ├── main.py
# ├── requirements.txt
# └── README.md
# ```
#
# **3. Роли**
# - Team Lead: **@viktoria_zhilyaeva** (Вика)
# - ML Engineer: **@imyourmilla** (Милана)
# - Data Engineer: **@oladyia** (Оля)
# - Документация/тесты: **@litlsun** (Катя)
#
# **4. Таймлайн**
# - **День 1:** поиск данных, подбор датасета
# - **День 2-6:** EDA, feature-engineering, preprocessing
# - **День 7-8:** baseline модель, метрики
# - **День 9-10:** улучшение, эксперименты
# - **День 11-14:** оформление, тесты, презентация
#
# ---
